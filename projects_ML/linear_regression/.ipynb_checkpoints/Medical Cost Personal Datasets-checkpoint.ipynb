# %% [markdown]
# # Medical Cost Personal Datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn import cross_validation, metrics
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
# %matplotlib inline

# %%
df=pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.barplot(x='sex', y='charges', data=df)

# %%
sns.barplot(x='children', y='charges', data=df)

# %%
sns.barplot(x='smoker', y='charges', data=df)

# %%
sns.barplot(x='region', y='charges', data=df)

# %%
sns.distplot(df['charges'])

# %%
sns.pairplot(df, hue='smoker')

# %% [markdown]
# - As Age and BMI go up Charges for health insurance also trends up.
#
# - No obvious connection between Charges and Age.
#
# - Charges for Smokers are higher for non-smokers.
#
# - No obvious connection between Charges and Region.

# %%
numeric=LabelEncoder()
df['sex']=numeric.fit_transform(df['sex'])
df['smoker']=numeric.fit_transform(df['smoker'])

# %%
regions=pd.get_dummies(df['region'], drop_first=True)

# %%
df = pd.concat([df,regions],axis=1)
df.drop('region', inplace=True, axis=1)

# %%
df.sample(10)
# Out:
#       age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 878    41    1  28.800         1       0   6282.23500          0          0
# 1299   19    0  25.745         1       0   2710.82855          1          0
# 423    25    1  30.590         0       0   2727.39510          0          0
# 214    45    0  30.900         2       0   8520.02600          0          0
# 283    55    0  32.395         1       0  11879.10405          0          0
# 268    45    1  30.200         1       0   7441.05300          0          0
# 699    23    0  39.270         2       0   3500.61230          0          1
# 735    49    0  34.770         1       0   9583.89330          1          0
# 1113   28    0  26.315         3       0   5312.16985          1          0
# 1300   45    1  30.360         0       1  62592.87309          0          1
#
#       southwest
# 878           1
# 1299          0
# 423           0
# 214           1
# 283           0
# 268           1
# 699           0
# 735           0
# 1113          0
# 1300          0

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr=pd.DataFrame(np.corrcoef(df.values.T), df.columns, df.columns)
corr
# Out:
#                 age       sex       bmi  children    smoker   charges  \
# age        1.000000 -0.019814  0.109344  0.041536 -0.025587  0.298308
# sex       -0.019814  1.000000  0.046397  0.017848  0.076596  0.058044
# bmi        0.109344  0.046397  1.000000  0.012755  0.003746  0.198401
# children   0.041536  0.017848  0.012755  1.000000  0.007331  0.067389
# smoker    -0.025587  0.076596  0.003746  0.007331  1.000000  0.787234
# charges    0.298308  0.058044  0.198401  0.067389  0.787234  1.000000
# northwest  0.001495 -0.012482 -0.136138  0.026044 -0.036321 -0.038695
# southeast -0.012311  0.017578  0.270057 -0.023492  0.068282  0.073578
# southwest  0.009415 -0.003767 -0.006211  0.021538 -0.037168 -0.043637
#
#            northwest  southeast  southwest
# age         0.001495  -0.012311   0.009415
# sex        -0.012482   0.017578  -0.003767
# bmi        -0.136138   0.270057  -0.006211
# children    0.026044  -0.023492   0.021538
# smoker     -0.036321   0.068282  -0.037168
# charges    -0.038695   0.073578  -0.043637
# northwest   1.000000  -0.345909  -0.320493
# southeast  -0.345909   1.000000  -0.346614
# southwest  -0.320493  -0.346614   1.000000

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(corr,mask=mask, annot=True, square=True, cmap='coolwarm')

# %%
cols=df.columns.values
X=df[[col for col in cols if col!='charges']]
Y=df['charges']

# %%
scaler=StandardScaler()
df[cols]=scaler.fit_transform(df[cols])

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.3)

# %%
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions=model.predict(X_test)

# %%
sns.distplot(predictions-y_test)

# %%
metrics.explained_variance_score(y_pred=predictions, y_true=y_test)
#model.score(X_test, y_test)
# Out:
# 0.78989950889520788

# %%
metrics.mean_squared_error(y_pred=predictions, y_true=y_test)
# Out:
# 0.20704500628953826

# %%
plt.scatter(y_test,predictions)

# %%
coeffecients = pd.DataFrame(model.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#            Coeffecient
# age           0.020920
# sex           0.002643
# bmi           0.028023
# children      0.035148
# smoker        1.943865
# northwest    -0.031558
# southeast    -0.098358
# southwest    -0.092531

# %%
model.intercept_
# Out:
# -2.0468053749761954

# %%
cols
# Out:
# array(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'], dtype=object)

# %%
results = smf.ols('charges ~ age+sex+bmi+children+smoker+northwest+southeast+southwest',data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     500.0
# Date:                Thu, 05 Jul 2018   Prob (F-statistic):               0.00
# Time:                        23:16:03   Log-Likelihood:                -968.38
# No. Observations:                1337   AIC:                             1955.
# Df Residuals:                    1328   BIC:                             2002.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -9.888e-17      0.014  -7.22e-15      1.000      -0.027       0.027
# age            0.2978      0.014     21.555      0.000       0.271       0.325
# sex           -0.0053      0.014     -0.389      0.698      -0.032       0.022
# bmi            0.1709      0.014     11.857      0.000       0.143       0.199
# children       0.0473      0.014      3.443      0.001       0.020       0.074
# smoker         0.7952      0.014     57.693      0.000       0.768       0.822
# northwest     -0.0124      0.017     -0.732      0.464      -0.045       0.021
# southeast     -0.0381      0.018     -2.162      0.031      -0.073      -0.004
# southwest     -0.0340      0.017     -2.008      0.045      -0.067      -0.001
# ==============================================================================
# Omnibus:                      299.816   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              716.552
# Skew:                           1.211   Prob(JB):                    2.53e-156
# Kurtosis:                       5.646   Cond. No.                         2.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
results = smf.ols('charges ~ age+bmi+children+smoker',data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     996.5
# Date:                Thu, 05 Jul 2018   Prob (F-statistic):               0.00
# Time:                        23:16:07   Log-Likelihood:                -971.65
# No. Observations:                1337   AIC:                             1953.
# Df Residuals:                    1332   BIC:                             1979.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -9.888e-17      0.014  -7.21e-15      1.000      -0.027       0.027
# age            0.2989      0.014     21.644      0.000       0.272       0.326
# bmi            0.1621      0.014     11.752      0.000       0.135       0.189
# children       0.0471      0.014      3.430      0.001       0.020       0.074
# smoker         0.7939      0.014     57.875      0.000       0.767       0.821
# ==============================================================================
# Omnibus:                      300.944   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              719.880
# Skew:                           1.215   Prob(JB):                    4.79e-157
# Kurtosis:                       5.650   Cond. No.                         1.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Ridge regression

# %%
X_train, X_test, y_train, y_test=cross_validation.train_test_split(X, Y, test_size=0.3)

# %%
alphas = 10**np.linspace(10,-2,100)*0.5

# %%
ridgecv = RidgeCV(alphas=alphas, scoring='neg_mean_squared_error')
ridgecv.fit(X_train, y_train)
ridgecv.alpha_
# Out:
# 0.0050000000000000001

# %%
ridge = Ridge(alpha=ridgecv.alpha_)
ridge.fit(X_train, y_train)
metrics.mean_squared_error(y_test, ridge.predict(X_test))
# Out:
# 0.26933589590828588

# %%
metrics.explained_variance_score(y_test, ridge.predict(X_test))
# Out:
# 0.73623644880827355

# %%
pd.Series(ridge.coef_, index=X.columns)
# Out:
# age          0.021664
# sex         -0.006823
# bmi          0.027290
# children     0.048974
# smoker       1.948004
# northwest   -0.035437
# southeast   -0.112310
# southwest   -0.085138
# dtype: float64

# %% [markdown]
# ## Lasso Regression

# %%
lassocv = LassoCV(alphas=None, cv=10, max_iter=100000)
lassocv.fit(X_train, y_train)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=10, eps=0.001, fit_intercept=True,
#     max_iter=100000, n_alphas=100, n_jobs=1, normalize=True,
#     positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=False)

# %%
lasso = Lasso(max_iter=10000)
lasso.set_params(alpha=lassocv.alpha_)
lasso.fit(X_train, y_train)
metrics.mean_squared_error(y_test, lasso.predict(X_test))
# Out:
# 0.26853123957885383

# %%
metrics.explained_variance_score(y_test, lasso.predict(X_test))
# Out:
# 0.73693437679719476

# %%
pd.Series(lasso.coef_, index=X.columns)
# Out:
# age          0.021394
# sex         -0.000000
# bmi          0.025991
# children     0.044188
# smoker       1.942041
# northwest   -0.000000
# southeast   -0.069502
# southwest   -0.044253
# dtype: float64
