# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
# %matplotlib inline

# %%
df=pd.read_csv('voice.csv')

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...    centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...    0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...    0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...    0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...    0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...    0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
# meanfreq    3168 non-null float64
# sd          3168 non-null float64
# median      3168 non-null float64
# Q25         3168 non-null float64
# Q75         3168 non-null float64
# IQR         3168 non-null float64
# skew        3168 non-null float64
# kurt        3168 non-null float64
# sp.ent      3168 non-null float64
# sfm         3168 non-null float64
# mode        3168 non-null float64
# centroid    3168 non-null float64
# meanfun     3168 non-null float64
# minfun      3168 non-null float64
# maxfun      3168 non-null float64
# meandom     3168 non-null float64
# mindom      3168 non-null float64
# maxdom      3168 non-null float64
# dfrange     3168 non-null float64
# modindx     3168 non-null float64
# label       3168 non-null object
# dtypes: float64(20), object(1)
# memory usage: 519.8+ KB

# %%
#number=LabelEncoder()
#df['label']=number.fit_transform(df['label'])

# %%
df['label']=df['label'].map({'male':0, 'female':1})

# %%
predictors=[col for col in df.columns if col!='label']

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(df[predictors])

# %%
X_scaled
# Out:
# array([[-4.04924806,  0.4273553 , -4.22490077, ..., -1.43142165,
#         -1.41913712, -1.45477229],
#        [-3.84105325,  0.6116695 , -3.99929342, ..., -1.41810716,
#         -1.4058184 , -1.01410294],
#        [-3.46306647,  1.60384791, -4.09585052, ..., -1.42920257,
#         -1.41691733, -1.06534356],
#        ...,
#        [-1.29877326,  2.32272355, -0.05197279, ..., -0.5992661 ,
#         -0.58671739,  0.17588664],
#        [-1.2452018 ,  2.012196  , -0.01772849, ..., -0.41286326,
#         -0.40025537,  1.14916112],
#        [-0.51474626,  2.14765111, -0.07087873, ..., -1.27608595,
#         -1.2637521 ,  1.47567886]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, df['label'].values, test_size=0.3)

# %%
cov_matrix = np.cov(X_train.T)
eig_vals, eig_vects=np.linalg.eig(cov_matrix)
eig_pairs=list(zip(eig_vals,eig_vects.T))
eig_pairs.sort(reverse=True)
sorted_eigVals=[eig_pairs[ind][0] for ind in range(len(eig_pairs))]
sorted_eigVects=[eig_pairs[ind][1] for ind in range(len(eig_pairs))]
var_exp=[var/sum(sorted_eigVals) for var in sorted_eigVals]
var_cum=np.cumsum(sorted_eigVals)/sum(sorted_eigVals)
var_cum
# Out:
# array([0.45182732, 0.57193522, 0.67695272, 0.75337368, 0.80672435,
#        0.8549335 , 0.88738962, 0.91650776, 0.94083376, 0.95950652,
#        0.97599209, 0.98515246, 0.99207607, 0.99675307, 0.99899092,
#        0.99959503, 1.        , 1.        , 1.        , 1.        ])

# %%
plt.figure(figsize=(8,8))
plt.step(range(1,len(sorted_eigVals)+1), var_cum, where='mid', label='cumulative explained variance', color='k')
plt.bar(range(1,len(sorted_eigVals)+1), var_exp, label='individual explained variance', color='r')
plt.xticks(range(1,len(sorted_eigVals)+1))
plt.legend()
plt.xlabel("Principal Components")
plt.ylabel("Cumulative proportion of variance retained")
plt.title("Retained variance")
# Out:
# Text(0.5,1,'Retained variance')

# %%
pca=PCA(n_components=8)
pca_model=pca.fit_transform(X_train)

# %%
y_train.shape
# Out:
# (2217,)

# %%
label=['male', 'female']
for i in range (2):
    plt.scatter(pca_model[np.where(y_train==i)[0],0], pca_model[np.where(y_train==i)[0],1], label=label[i])
    plt.legend()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
xs = pca_model[:,0]
ys = pca_model[:,1]
zs = pca_model[:,2]
for i in range (2):
    ax.scatter(pca_model[np.where(y_train==i)[0],0], pca_model[np.where(y_train==i)[0],1], pca_model[np.where(y_train==i)[0],2], label=label[i])
    ax.legend()

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# Text(0.5,0,'Z Label')

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans, dbscan

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(pca_model)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
for i in range (2):
    plt.scatter(pca_model[np.where(kmeans.labels_==i)[0],0], pca_model[np.where(kmeans.labels_==i)[0],1], label=i)
    plt.legend()
